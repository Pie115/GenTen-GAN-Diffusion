# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rank_axis = [5, 10, 25, 50, 100, 150, 200, 250]
FID_axis = [53.59, 53.89, 37.14, 21.12, 16.01, 19.04, 18.71, 25.66]

# %%
plt.figure(figsize=(6, 4))
plt.plot(rank_axis, FID_axis, color='black', linewidth=2)
plt.xlabel('Rank', fontsize=12)
plt.ylabel('FID Score', fontsize=12)
plt.title('Rank vs FID', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, 65)

plt.text(0.5, -0.18, '(b) Diffusion', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)

plt.tight_layout()

plt.savefig("FID_Rank_Diffusion")

# %%
rank_axis = [5, 10, 25, 50, 100, 150, 200, 250]
FID_axis = [48.12, 45.42, 41.38, 18.99, 18.37, 18.30, 18.19, 25.29]

# %%
plt.figure(figsize=(6, 4))
plt.plot(rank_axis, FID_axis, color='black', linewidth=2)
plt.xlabel('Rank', fontsize=12)
plt.ylabel('FID Score', fontsize=12)
plt.title('Rank vs FID', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, 65)

plt.text(0.5, -0.18, '(b) Diffusion', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)

plt.tight_layout()

plt.savefig("FID_Rank_Diffusion")

# %%
rank_axis = [5, 10, 25, 50, 100, 150, 200, 250]
FID_axis = [40.58, 44.12, 43.96, 20.37, 24.76, 17.09, 16.65, 17.30]

# %%
plt.figure(figsize=(6, 4))
plt.plot(rank_axis, FID_axis, color='black', linewidth=2)
plt.xlabel('Rank', fontsize=12)
plt.ylabel('FID Score', fontsize=12)
plt.title('Rank vs FID', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, 65)

plt.text(0.5, -0.18, '(b) Diffusion', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)

plt.tight_layout()

plt.savefig("FID_Rank_Diffusion")

# %%
parameter_axis = [1.26, 1.85, 3.61, 6.54, 12.41, 18.28, 24.15, 30.02]


FID_axis = [48.12, 44.12, 41.38, 18.99, 18.37, 18.30, 18.19, 17.30]

plt.plot(parameter_axis, FID_axis, color='black', linewidth=4)
plt.xlabel('Parameters (in millions)', fontsize=20)
plt.ylabel('FID Score', fontsize=20)
plt.title('Parameters vs FID', fontsize=34)
plt.xticks(fontsize=15)
plt.yticks(np.arange(0, 51, 5), fontsize=15)
plt.ylim(0, 50)
plt.text(0.5, -0.18, None, ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)

plt.tight_layout()

plt.savefig("Diffusion_parameters_vs_FID")
